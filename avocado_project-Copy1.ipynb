# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1               1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2               2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3               3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4               4  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  04-02-2018          1.63      17074.83  2046.96    1529.20
# 18245           8  28-01-2018          1.71      13888.04  1191.70    3431.50
# 18246           9  21-01-2018          1.87      13766.76  1191.92    2452.79
# 18247          10  14-01-2018          1.93      16205.22  1527.63    2981.04
# 18248          11  07-01-2018          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.shape
# Out:
# (18249, 13)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
df['Year'], df['Month'], df['Day'] = df['Date'].str.split('-').str
df.drop(columns=['Date','year'], inplace=True)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type            region  \
# 0         8603.62       93.25          0.0  conventional            Albany
# 1         9408.07       97.49          0.0  conventional            Albany
# 2         8042.21      103.14          0.0  conventional            Albany
# 3         5677.40      133.76          0.0  conventional            Albany
# 4         5986.26      197.69          0.0  conventional            Albany
# ...           ...         ...          ...           ...               ...
# 18244    13066.82      431.85          0.0       organic  WestTexNewMexico
# 18245     8940.04      324.80          0.0       organic  WestTexNewMexico
# 18246     9351.80       42.31          0.0       organic  WestTexNewMexico
# 18247    10919.54       50.00          0.0       organic  WestTexNewMexico
# 18248    11988.14       26.01          0.0       organic  WestTexNewMexico
#
#       Year Month   Day
# 0       27    12  2015
# 1       20    12  2015
# 2       13    12  2015
# 3       06    12  2015
# 4       29    11  2015
# ...    ...   ...   ...
# 18244   04    02  2018
# 18245   28    01  2018
# 18246   21    01  2018
# 18247   14    01  2018
# 18248   07    01  2018
#
# [18249 rows x 14 columns]

# %%
df['Year']=df['Year'].astype(int)
df['Month']=df['Month'].astype(int)
df['Date']=df['Day'].astype(int)
df.drop(columns=['Day'], inplace=True)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type            region  \
# 0         8603.62       93.25          0.0  conventional            Albany
# 1         9408.07       97.49          0.0  conventional            Albany
# 2         8042.21      103.14          0.0  conventional            Albany
# 3         5677.40      133.76          0.0  conventional            Albany
# 4         5986.26      197.69          0.0  conventional            Albany
# ...           ...         ...          ...           ...               ...
# 18244    13066.82      431.85          0.0       organic  WestTexNewMexico
# 18245     8940.04      324.80          0.0       organic  WestTexNewMexico
# 18246     9351.80       42.31          0.0       organic  WestTexNewMexico
# 18247    10919.54       50.00          0.0       organic  WestTexNewMexico
# 18248    11988.14       26.01          0.0       organic  WestTexNewMexico
#
#        Year  Month  Date
# 0        27     12  2015
# 1        20     12  2015
# 2        13     12  2015
# 3         6     12  2015
# 4        29     11  2015
# ...     ...    ...   ...
# 18244     4      2  2018
# 18245    28      1  2018
# 18246    21      1  2018
# 18247    14      1  2018
# 18248     7      1  2018
#
# [18249 rows x 14 columns]

# %%
sns.countplot(x='type',data=df,palette="BrBG_r")
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
sns.countplot(x='Year',data=df,palette="BrBG_r")
df['Year'].value_counts()
# Out:
# 11    756
# 4     756
# 18    755
# 25    755
# 8     648
# 12    648
# 24    648
# 1     648
# 26    648
# 22    648
# 5     648
# 19    648
# 3     648
# 15    648
# 17    648
# 10    648
# 27    540
# 28    540
# 7     540
# 14    540
# 29    540
# 21    540
# 20    540
# 13    540
# 6     539
# 30    432
# 16    432
# 9     432
# 23    432
# 2     432
# 31    432
# Name: Year, dtype: int64

# %%
df.hist(figsize=(15,10),bins=10)
plt.figure(figsize=(10,4))
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Year',y='Total Volume',hue='type',data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Volume'>

# %%
df.plot(kind='box',subplots=True,layout=(3,6))
# Out:
# AveragePrice       AxesSubplot(0.125,0.657941;0.110714x0.222059)
# Total Volume    AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# 4046            AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# 4225            AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 4770            AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# Total Bags      AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# Small Bags         AxesSubplot(0.125,0.391471;0.110714x0.222059)
# Large Bags      AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# XLarge Bags     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# Year            AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# Month           AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# Date            AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['region']=LE.fit_transform(df['region'].values.reshape(-1,1))
df['type']=LE.fit_transform(df['type'].values.reshape(-1,1))
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Year  Month  Date
# 0         8603.62       93.25          0.0     0       0    27     12  2015
# 1         9408.07       97.49          0.0     0       0    20     12  2015
# 2         8042.21      103.14          0.0     0       0    13     12  2015
# 3         5677.40      133.76          0.0     0       0     6     12  2015
# 4         5986.26      197.69          0.0     0       0    29     11  2015
# ...           ...         ...          ...   ...     ...   ...    ...   ...
# 18244    13066.82      431.85          0.0     1      53     4      2  2018
# 18245     8940.04      324.80          0.0     1      53    28      1  2018
# 18246     9351.80       42.31          0.0     1      53    21      1  2018
# 18247    10919.54       50.00          0.0     1      53    14      1  2018
# 18248    11988.14       26.01          0.0     1      53     7      1  2018
#
# [18249 rows x 14 columns]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
# removing outliers

from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.18868864, 0.22771641, 0.23081597, ..., 1.29185687, 1.64763162,
#         1.22128204],
#        [0.13901962, 0.23042664, 0.23110251, ..., 0.49423066, 1.64763162,
#         1.22128204],
#        [1.18206895, 0.21208462, 0.23100731, ..., 0.30339555, 1.64763162,
#         1.22128204],
#        ...,
#        [1.15237477, 0.24233073, 0.2306933 , ..., 0.60817726, 1.46495942,
#         1.97050371],
#        [1.30138182, 0.24162464, 0.2304279 , ..., 0.18944895, 1.46495942,
#         1.97050371],
#        [0.53151208, 0.24125273, 0.22934712, ..., 0.98707516, 1.46495942,
#         1.97050371]])

# %%
threshold=3
print(np.where(z<3))
# Out:
# (array([    0,     0,     0, ..., 18248, 18248, 18248], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Year  Month  Date
# 0         8603.62       93.25          0.0     0       0    27     12  2015
# 1         9408.07       97.49          0.0     0       0    20     12  2015
# 2         8042.21      103.14          0.0     0       0    13     12  2015
# 3         5677.40      133.76          0.0     0       0     6     12  2015
# 4         5986.26      197.69          0.0     0       0    29     11  2015
# ...           ...         ...          ...   ...     ...   ...    ...   ...
# 18244    13066.82      431.85          0.0     1      53     4      2  2018
# 18245     8940.04      324.80          0.0     1      53    28      1  2018
# 18246     9351.80       42.31          0.0     1      53    21      1  2018
# 18247    10919.54       50.00          0.0     1      53    14      1  2018
# 18248    11988.14       26.01          0.0     1      53     7      1  2018
#
# [17651 rows x 14 columns]

# %%
# Splitting the Dataset


x = df_new.drop("AveragePrice",axis=1)
y = df_new["AveragePrice"]

# %%
# scaling 

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=45)

# %%
x_train.shape
# Out:
# (11826, 13)

# %%
x_test.shape
# Out:
# (5825, 13)

# %%
#LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.4417807540943878

# %%
print(mean_squared_error(LR_predict,y_test))
print(mean_absolute_error(LR_predict,y_test))
print(r2_score(LR_predict,y_test))
# Out:
# 0.08259885468868056
# 0.225394928224296
# -0.24931533765616876

# %%
#Random Forest Regressor

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
print(rf.score(x_train,y_train))
rf_PRED=rf.predict(x_test)

# %%
#SVR

from sklearn.svm import SVR
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
